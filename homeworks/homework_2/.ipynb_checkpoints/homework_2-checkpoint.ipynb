# %% [markdown]
# # Homework 2

# %% [markdown]
# In this homework you will be performing some analysis with entity extraction. In particular, you will be looking at the Reuters corpus and trying to construct entity profiles of persons, organizations, and locations. This will require you to iterate through the documents in the Reuters corpus, parse them appropriately, extract entities, and then store the entities along with some surrounding text. Additionally, you will be looking for mechanisms to identify potential relationships between persons and locations.
#
# Throughout this you will need to use NLTK to access the corpus. At the same time, you will need to use an entity extraction system. You can choose to use either NLTK or Spacy. I would strongly suggest using Spacy for the entity extraction portion of this assignment.
#
# The basic idea is to build a knowledge base around the entities you will extract in the Reuters corpus. Normally, this would be a first step to trying to model such things as entity resolution across documents. You could also use this as a first step to analyzing the sentiment towards particular entities. For example, people expressing dissatistfaction at a restaurant or brand.
#
# Follow the below steps and read the comments carefully on the types of tasks your code will need to do.
#
# I would expect that some of you might be able to reuse parts of this code for your project...

# %% [markdown]
# ## Step 1) Import necessary libraries

# %%
# This will be the corpus we work from
from nltk.corpus import reuters, stopwords
from nltk.tokenize import TreebankWordTokenizer
stop_words = stopwords.words('english')
treebank_tokenizer = TreebankWordTokenizer()

# %%
# I will assume you are using Spacy as a default entity recognizer.
import spacy
# note, the model load can be odd. In some instances your model might have the full name or the short name here.
# if you run into issues here, check the spacy model page at https://spacy.io/usage/models
nlp = spacy.load("en")

# %% [markdown]
# ## Step 2) FIll in the following function to extract the entity, document id, and relevant sentence text from the input

# %%
def extract_entities(doc_id, doc_text):
    analyzed_doc = nlp(doc_text)
    
    # these two dictionaries will include all the persons and locations you find in a document.
    # You will need to add each person or location you encounter in the document to them
    # for the key you can use the text of the entity, for the value you will want to use the document_id and the
    # text of the sentence one challenge could be that an entity might occur multiple times in the document, 
    # thus the value should really be a document id and a list of the text of the sentences ( or something such as that)
    doc_persons = {}
    doc_organizations = {}
    doc_locations = {}
    
    for entity in analyzed_doc.ents:
        if entity.text.strip() != "":
#             # The .label_ property will provide information on the type of entity tagged
#             print(" -> ", entity.label_)
#             # The .text property will display the actual text of the entity in the text
#             print("->", entity.text.strip(), "<-")
#             # You can also access the sentence that the entity is contained in by using the .sent property
#             # inside the sentence you can then use the .text property
#             print("->", entity.sent.text, "<-")
            
            
            # one way to represent the document id and the sentence text would be with a tuple
            # thus, you could do:
            relevant_sentence = (doc_id, entity.sent.text)
#             print('relevant:', relevant_sentence)
            
            # add the relevant document id and sentence to the entity record
            if entity.label_ == 'PERSON':
                doc_persons.setdefault(entity.text.strip(), []).append(relevant_sentence)
            elif entity.label_ == 'ORG':
                doc_organizations.setdefault(entity.text.strip(), []).append(relevant_sentence)
            elif entity.label_ == 'LOC':
                doc_locations.setdefault(entity.text.strip(), []).append(relevant_sentence)
            
            
    return doc_persons, doc_organizations, doc_locations

# %% [markdown]
# ## Step 3) Adjust the following code to run the document entity extraction function
# ## Also, add the entity records you are constructing to your master list of entities
# ## Note: for the full subission run across all the Reuters documents

# %%
num_docs = len(reuters.fileids())
#  this has a large number of files... 
# you might wish to limit the number of documents you use while developing your technique 
# ex. reuters.fileids()[0:25]

# these two dictionaries will incorporate all the referneces to 
combined_persons = {}
combined_organizations = {}
combined_locations = {}

# this will only iterate over the first 25 documents, for the real submission you will need to run across all documents
for doc_id in reuters.fileids(): 
    # this doc_text variable will give you a text version of the news article. This could be tokenized.
    persons, organizations, locations = extract_entities(doc_id, reuters.open(doc_id).read())
    
    # you will need to write something here to put the persons and locations found in a document into the 
    # combined_persons, combined_organizations, and combined_locations dictionaries.
    # here you will need to consider how to extend the values already in the dictionaries
    # maybe something like:
    # for person in persons.keys():
    #     if person not in combined_persons.keys():
    #         --- add a person key to the combined persons list
    #     now here you can add the person's document ids and sentence texts to the dictionary value
    
    for person in persons.keys():
        if person not in combined_persons.keys():
            combined_persons[person] = persons[person]
        else:
            combined_persons[person] += persons[person]
            
    for org in organizations.keys():
        if org not in combined_organizations.keys():
            combined_organizations[org] = organizations[org]
        else:
            combined_organizations[org] += organizations[org]
            
    for loc in locations.keys():
        if loc not in combined_locations.keys():
            combined_locations[loc] = locations[loc]
        else:
            combined_locations[loc] += locations[loc]

# %% [markdown]
# ## Step 4) Fill in the following method to look through the content of an entity dictionary to determine the most popular based on number of mentions

# %%
# now that we have the text associated with the entities, 
# you will want to focus on the 500 top entities in each category
# Identify the top 500 entities by the count of their occurrences
def find_most_popular_entities(entity_dictionary):
    # sort through the entities in the dictionary by the number of sentences
    list_of_dictionary_keys_with_most_mentions = sorted(entity_dictionary, 
                                                        key=lambda x: len(entity_dictionary[x]), 
                                                        reverse=True)
    
    return list_of_dictionary_keys_with_most_mentions[:500]

# %%
dic = {'A': [1,2], 'B': [2,3,4], 'C': [0], 'D': [1,2,3,4,4]}

# %%
sorted(dic, key=lambda x: len(dic[x]), reverse=True)
# Out:
# ['D', 'B', 'A', 'C']

# %% [markdown]
# ## Step 5) Now invoke your top entity mention finder

# %%
# simply get the top persons and locations
top_persons = find_most_popular_entities(combined_persons)
top_locations = find_most_popular_entities(combined_locations)
top_organizations = find_most_popular_entities(combined_organizations)

# %%
len(top_persons)
# Out:
# 500

# %%
len(top_locations)
# Out:
# 500

# %%
len(top_organizations)
# Out:
# 500

# %% [markdown]
# ## Step 6) Analyze the most popular entities to determine what words they most frequently occur with

# %%
# use these dictionaries to store the most frequent terms associated with the entities
person_most_popular_terms = {}
organization_most_popular_terms = {}
location_most_popular_terms = {}

def find_most_frequent_term(top_persons, combined_persons):
    person_most_popular_terms = {}
    # finally, now find the most frequent tokens associated with the entities
    for person in top_persons:
        # fill this dictionary with all the words in the context of the person entity
        person_token_dictionary = {}
        sentences_words = [treebank_tokenizer.tokenize(sentence[1]) for sentence in combined_persons[person]]
        all_tokens = [word for sentence in sentences_words for word in sentence]
        for word in all_tokens:
            # remove the stop words, numbers, and punctuations
            if word.isalpha() and (word.lower() not in stop_words) and (word not in person):
                person_token_dictionary.setdefault(word, 0)
                person_token_dictionary[word] += 1
        try:
            person_most_popular_terms[person] = max(person_token_dictionary, 
                                                    key=lambda x: person_token_dictionary[x])
        except: pass
        
    return person_most_popular_terms

person_most_popular_terms = find_most_frequent_term(top_persons, combined_persons)

# finally, now find the most frequent tokens associated with the entities
organization_most_popular_terms = find_most_frequent_term(top_organizations, combined_organizations)
    
location_most_popular_terms = find_most_frequent_term(top_locations, combined_locations)

# %%
person_most_popular_terms
# Out:
# {'Avg': 'vs',
#  'Reagan': 'said',
#  'Baker': 'said',
#  'Lawson': 'said',
#  'Yeutter': 'said',
#  'James Baker': 'Treasury',
#  'Poehl': 'said',
#  'Ecus': 'European',
#  'Stoltenberg': 'said',
#  'Baldrige': 'said',
#  'Purolator': 'Hutton',
#  'Volcker': 'said',
#  'Clayton Yeutter': 'Trade',
#  'Brown': 'AFG',
#  'Louvre': 'said',
#  'Kiichi Miyazawa': 'Finance',
#  'Johnson': 'said',
#  'Herrington': 'said',
#  'Yasuhiro Nakasone': 'Prime',
#  'Rotterdam': 'said',
#  '1986/87': 'tonnes',
#  'Dart': 'said',
#  'Lyng': 'said',
#  'Bass': 'said',
#  'Sosnoff': 'said',
#  'Gencorp': 'said',
#  'Richard Lyng': 'Agriculture',
#  'Satoshi Sumita': 'Japan',
#  'Prev Wk': 'WK',
#  'Nazer': 'said',
#  'Banks': 'billion',
#  'Williams': 'mln',
#  'Clayton': 'Yeutter',
#  'Subroto': 'said',
#  'Nigel Lawson': 'Chancellor',
#  'Redstone': 'said',
#  'Karl Otto Poehl': 'Bundesbank',
#  'Wagner': 'AFG',
#  'Wendy': 'said',
#  'Icahn': 'USAir',
#  'Heller': 'said',
#  'Edouard Balladur': 'Minister',
#  'Dome': 'said',
#  'REAGAN': 'SAYS',
#  'Caspar Weinberger': 'Secretary',
#  'Chirac': 'said',
#  'Huckaby': 'sugar',
#  'Lukman': 'said',
#  'Conrac': 'said',
#  'Paul Volcker': 'Federal',
#  'Malcolm Baldrige': 'Secretary',
#  'Mark IV': 'Baird',
#  'Miyazawa': 'Japanese',
#  'Clark': 'said',
#  'Dauster': 'said',
#  'Gerhard Stoltenberg': 'Finance',
#  'Darman': 'Baker',
#  'Mannesmann': 'said',
#  '1987/88': 'said',
#  'Simon': 'said',
#  'Monier': 'said',
#  'Shr': 'vs',
#  'Domes Use': 'NIL',
#  'Sumita': 'said',
#  'mln': 'vs',
#  'Watanabe': 'said',
#  'Jardine Matheson': 'said',
#  'George Shultz': 'Secretary',
#  'Jorio Dauster': 'said',
#  'Rainbow': 'Progressive',
#  'Mulroney': 'said',
#  'Reuter': 'correspondents',
#  'Morgan': 'mln',
#  'Donald Trump': 'estate',
#  'Marlin Fitzwater': 'spokesman',
#  'Carney': 'said',
#  'Gabelli': 'said',
#  'Margaret Thatcher': 'Prime',
#  'Bangemann': 'said',
#  'Heyman': 'said',
#  'Leigh-Pemberton': 'said',
#  'BAKER': 'SAYS',
#  'Petrobras': 'said',
#  'Xuto': 'said',
#  'Kim': 'said',
#  'Trump': 'said',
#  'Fitzwater': 'said',
#  'Sprinkel': 'said',
#  'Moore': 'said',
#  'Backlog': 'mln',
#  'Romero': 'said',
#  'Santos': 'said',
#  'Phillips': 'oil',
#  'Keating': 'said',
#  'Roderick': 'said',
#  'Silas': 'said',
#  'Roberts': 'said',
#  'Harris': 'said',
#  'Howard': 'said',
#  'Jones': 'said',
#  'Paul\n  Volcker': 'said',
#  'Nigel': 'Chancellor',
#  'Roach': 'mln',
#  'Jordan': 'said',
#  'Yulo': 'said',
#  'John Herrington': 'oil',
#  'Kato': 'Japan',
#  'Corazon Aquino': 'President',
#  'Cominco': 'pct',
#  'Rexham': 'Nortek',
#  'Sullivan': 'mln',
#  'Gobert': 'Dome',
#  'Reynolds': 'said',
#  'Conger': 'said',
#  'Qtr': 'ends',
#  'Fernandez': 'said',
#  'Bilzerian': 'said',
#  'Azpurua': 'said',
#  'Sims': 'said',
#  'Jim Wright': 'House',
#  'Durham': 'said',
#  'Dan Glickman': 'subcommittee',
#  'Fernando Santos Alvite': 'Ecuador',
#  'Eyskens': 'said',
#  'Mueller': 'said',
#  'Haggard': 'soybean',
#  'Dole': 'said',
#  'Denman': 'trade',
#  'McIvor': 'said',
#  'Charter': 'dlrs',
#  'Miller': 'said',
#  'Keidanren': 'Eishiro',
#  'Gelco': 'units',
#  'McCarthy': 'said',
#  'Honeywell': 'said',
#  'Hisham Nazer': 'Saudi',
#  'Sarney': 'foreign',
#  'Citgo': 'West',
#  'Jacques Chirac': 'Minister',
#  'Suharto': 'President',
#  'James Capel': 'said',
#  'Richard\n  Lyng': 'said',
#  'Daniel Amstutz': 'said',
#  'Hernandez': 'said',
#  'De Croo': 'said',
#  'Gardner': 'said',
#  'Smith': 'dlrs',
#  'Gaviria': 'said',
#  'Asher Edelman': 'Inc',
#  'Michael Wilson': 'Finance',
#  'Southmark': 'said',
#  'BALDRIGE': 'SAYS',
#  'Hajime Tamura': 'Trade',
#  'Jovanovich Inc': 'Harcourt',
#  'Inc': 'said',
#  'Greenspan': 'dollar',
#  'Rilwanu Lukman': 'OPEC',
#  'Kay': 'said',
#  'Kahan': 'said',
#  'Carl Icahn': 'TWA',
#  'Boliden': 'would',
#  'SUPPLY': 'MONEY',
#  'Papandreou': 'Turkey',
#  'Danforth': 'said',
#  'Acquisition': 'General',
#  'Allegheny': 'said',
#  'Richard Gephardt': 'trade',
#  'Hutchison': 'Hongkong',
#  'Comdata': 'said',
#  'Manaspas Xuto': 'chairman',
#  'Li': 'said',
#  'Lee': 'said',
#  'Nogales': 'said',
#  'Pinola': 'said',
#  'Atlas': 'said',
#  'Kenneth Kaunda': 'President',
#  'Cordoba': 'Santa',
#  'Fleet': 'said',
#  'Eishiro Saito': 'Keidanren',
#  'Saito': 'said',
#  'Brennan': 'said',
#  'Giordano': 'said',
#  'Martin T. Sosnoff': 'said',
#  'Robert Brusca': 'Nikko',
#  'Blair': 'said',
#  'Ronald Reagan': 'President',
#  'Ortner': 'said',
#  'Trail': 'long',
#  "O'Neill": 'said',
#  'Wang': 'said',
#  'Computerland': 'said',
#  'Harkin': 'pct',
#  'Andriessen': 'said',
#  'Ali': 'said',
#  'Arturo Hernandez Grisanti': 'said',
#  'Myers': 'said',
#  'Callebaut': 'said',
#  'Mulford': 'said',
#  'Dudley Taft': 'vice',
#  'De Clercq': 'trade',
#  'Rostenkowski': 'trade',
#  'Swearingen': 'said',
#  'Preussag': 'said',
#  'Santana': 'said',
#  'Fendt': 'said',
#  'Wickes': 'would',
#  'Diaz': 'said',
#  'Ferdinand Marcos': 'former',
#  'Gerhard': 'West',
#  'Anderson': 'said',
#  'Stewart': 'Superior',
#  'Jorge Cardenas': 'coffee',
#  'Arango': 'said',
#  'Revenues': 'dlrs',
#  'Brent': 'dlrs',
#  'Helmut Schlesinger': 'Bundesbank',
#  'Schlesinger': 'said',
#  'Rice': 'said',
#  'Lichtblau': 'said',
#  'NOTE:1985': 'includes',
#  'Drew': 'said',
#  'Lloyd Bentsen': 'Senate',
#  'Bentsen': 'would',
#  'Corona': 'share',
#  'Comalco': 'said',
#  'Kahn': 'said',
#  'Buitoni': 'billion',
#  'Mercer': 'said',
#  'Marshall': 'said',
#  'Henderson': 'said',
#  'Conoco': 'lt',
#  'Malcolm': 'Secretary',
#  'Javier Espinosa': 'Ecuador',
#  'Zimmerman': 'Canadian',
#  'Stevens': 'pipeline',
#  'Gordon': 'said',
#  'Helmut Kohl': 'Chancellor',
#  'Mario Gabelli': 'shares',
#  'Affandi': 'sugar',
#  'Perelman': 'said',
#  'Sanford Margoshes': 'Shearson',
#  'Shad': 'said',
#  'Denis Bra': 'Kanon',
#  'A. William Reynolds': 'chairman',
#  'Hernandez Grisanti': 'said',
#  'Richard': 'Lyng',
#  'Willy De Clercq': 'EC',
#  'Metropolitan': 'Metex',
#  'Jacques Delors': 'Commission',
#  'Manuel Johnson': 'said',
#  'Kobena Erbynn': 'delegates',
#  'Gorbachev': 'said',
#  'Maekawa': 'report',
#  'Hanson': 'said',
#  'Gephardt': 'said',
#  'Lewis': 'said',
#  'Gardini': 'CPC',
#  'Melvin Sims': 'USDA',
#  'Dan Rostenkowski': 'chairman',
#  'Martin': 'said',
#  'Glickman': 'budget',
#  'Herrhausen': 'said',
#  'Bayer': 'said',
#  'Aziz': 'said',
#  'Martell': 'said',
#  'vs yr-ago': 'dlrs',
#  'Rha': 'said',
#  'Melnikov': 'said',
#  'Channon': 'trade',
#  'Kistler': 'said',
#  'Fairchild': 'said',
#  'King Fahd': 'Saudi',
#  'Balletto': 'said',
#  'Evans': 'government',
#  'Bennett': 'said',
#  'Czarnikow': 'tonnes',
#  'Cook': 'said',
#  'Mij': 'tonnes',
#  'De Zeeuw': 'said',
#  'Hawkeye': 'said',
#  'Gilberto Arango': 'president',
#  'Bahrain': 'banks',
#  'Lex': 'said',
#  'Cohen': 'dlrs',
#  'Barber Conable': 'Bank',
#  'Cotton': 'Valley',
#  'Ward McCarthy': 'said',
#  'Wilf Gobert': 'Co',
#  'James Goldsmith': 'Sir',
#  'Scott': 'mln',
#  'Triton': 'said',
#  'Rose': 'said',
#  'Maki': 'said',
#  'Brian Mulroney': 'Prime',
#  'Aramco': 'mln',
#  'Frans Andriessen': 'EC',
#  'Carl Lindner': 'Taft',
#  'Aga': 'pct',
#  'Nakasone': 'said',
#  'Jose Sarney': 'President',
#  'Glenn': 'said',
#  'Ronald Perelman': 'Revlon',
#  'Halcyon': 'said',
#  'Seger': 'said',
#  'Monfort': 'pct',
#  'Davis': 'Zealand',
#  'L.F. Rothschild': 'said',
#  'van Horick': 'said',
#  'Jacobs': 'comment',
#  'Rosenbaum': 'said',
#  'Rafsanjani': 'also',
#  'Martin Sosnoff': 'said',
#  'Patrick Leahy': 'Chairman',
#  'Mikhail Gorbachev': 'Soviet',
#  'Thatcher': 'said',
#  'McIntyre': 'Smoky',
#  'Taylor': 'said',
#  'Dunham': 'said',
#  'Lindner': 'Taft',
#  'AFG': 'Wagner',
#  'Dieter': 'said',
#  'Ranks Hovis': 'cash',
#  'van Driel': 'said',
#  'Krupp': 'said',
#  'Delegates': 'said',
#  'Iowa Beef': 'said',
#  'Bancroft': 'said',
#  'Soros': 'said',
#  'Solomon': 'said',
#  'Santos Alvite': 'last',
#  'Miles': 'said',
#  'Almir Pazzionotto': 'Labour',
#  'Ward': 'Guinness',
#  'Hiram Walker-Gooderham': 'year',
#  'Victor Paz Estenssoro': 'government',
#  "O'Reilly": 'said',
#  'Habbel': 'Audi',
#  'Meinhardt': 'pct',
#  'Kaske': 'said',
#  'Michael Smith': 'Deputy',
#  'Ramon Diaz': 'shares',
#  'Kiichi\n  Miyazawa': 'said',
#  'Andreas Papandreou': 'Prime',
#  'Showboat': 'interest',
#  'Gholamreza Aqazadeh': 'Minister',
#  'Heublein Inc': 'mln',
#  'Todd': 'said',
#  'Beryl Sprinkel': 'said',
#  'Foothill': 'said',
#  'Shamrock': 'shares',
#  'Goodrich': 'said',
#  'Marris': 'dollar',
#  'Lago Agrio': 'pipeline',
#  'Irwin Jacobs': 'pct',
#  'Henry Gluck': 'chairman',
#  'Gluck': 'said',
#  'Foster': 'mln',
#  'Nelson': 'said',
#  'Allan Leslie': 'said',
#  'Yasuhiro': 'Prime',
#  'Fahd': 'Saudi',
#  'Crazy Eddie': 'company',
#  'Gerhard\n  Stoltenberg': 'Finance',
#  'Kohl': 'Poehl',
#  'Lieberman': 'said',
#  'Alan Greenspan': 'said',
#  'Treasurer Paul Keating': 'Australian',
#  'Bass Strait': 'oil',
#  'Ganilau': 'said',
#  'Atlantic Richfield': 'said',
#  'Sanford C. Bernstein': 'said',
#  'Young': 'said',
#  'Lim Keng Yaik': 'Minister',
#  'Wright': 'plan',
#  'Seton': 'said',
#  'Hall': 'said',
#  'Hoare Govett': 'said',
#  'Kellogg': 'said',
#  'Yaacobi': 'said',
#  'Mir-Hossein': 'Iranian',
#  'Mousavi': 'Tehran',
#  'Richard Jeffrey': 'said',
#  'Chang Chi-cheng': 'bank',
#  'Diplomats': 'said',
#  'Talyzin': 'said',
#  'Hofmeister': 'rubber',
#  'Comissaria Smith': 'times',
#  'Tadashi Kuranari': 'Foreign',
#  'Alejandro Martinez': 'producers',
#  'Garcia': 'said',
#  'De Mel': 'said',
#  'Co': 'dlrs',
#  'Michael Jopling': 'British',
#  'Walsh': 'earnings',
#  'Wolf': 'said',
#  'Kramer': 'said',
#  'Pat Roberts': 'offer',
#  'Pratt': 'Sosnoff',
#  'Harlow': 'said',
#  'Stephens': 'said',
#  'Breakwater': 'Novamin',
#  'microchips': 'computer',
#  'Degussa': 'pct',
#  'Wormald': 'businesses',
#  'Nacco': 'Coal',
#  'Rainfall': 'mm',
#  'Lo': 'said',
#  'WCAS': 'Comdata',
#  'Ryan': 'said',
#  'Robert Ortner': 'Commerce',
#  'Fellner': 'said',
#  'Sheikh Ali': 'Kuwait',
#  'Zack': 'said',
#  'Narragansett': 'Taft',
#  'Mathematical Applications': 'said',
#  'Theodore Cross': 'share',
#  'Renouf': 'said',
#  'Knoll': 'American',
#  'Magma': 'dlrs',
#  'Jucker': 'said',
#  'Martens': 'government',
#  'Lerner': 'said',
#  'Gleske': 'target',
#  'Thomas': 'said',
#  'Sindt': 'USDA',
#  'Mike Moore': 'minister',
#  'Sugarman': 'offering',
#  'Chapman': 'Troon',
#  'Abu al-Bukhoosh': 'said',
#  'Masse': 'program',
#  'Kadoorie': 'family',
#  'Linde': 'Meinhardt',
#  'Mutsuki Kato': 'Agriculture',
#  'Edmonton': 'site',
#  'kilos': 'per',
#  'Kuroda': 'said',
#  'Keswick': 'said',
#  'Shintaro Abe': 'April',
#  'Francisco Gros': 'debt',
#  'Carson': 'said',
#  'Samuel Heyman': 'GAF',
#  'J.P. Morgan': 'Co',
#  'Rio Grande': 'states',
#  'Edelman': 'Lucky',
#  'Allen Wallis': 'State',
#  'Wallin': 'said',
#  'Kohlberg Kravis Roberts': 'Co',
#  'Robert Heller': 'said',
#  'Morrison': 'dlrs',
#  'Xebec': 'IBM',
#  'Day': 'said',
#  'Strata': 'share',
#  'Claus Koehler': 'Bundesbank',
#  'Cuevas': 'said',
#  'MM': 'NIL',
#  'Alex': 'Brown',
#  'Easter': 'April',
#  'mln tonnes': 'crop',
#  'pct sulphur': 'dlrs',
#  'SUPPLY FALLS': 'MONEY',
#  'Atcor': 'said',
#  'David Jones': 'said',
#  'Vincent Siew': 'told',
#  'Siew': 'said',
#  'David Annesley': 'Dome',
#  'Michel Noir': 'said',
#  'Condon': 'said',
#  'Merlin': 'pct',
#  'Nichols': 'said',
#  'palm olein': 'refined',
#  'Richard Darman': 'Treasury',
#  'Btu': 'dlrs',
#  'Mariano Rubio': 'said',
#  'Goodyear': 'said',
#  'Astra': 'pct',
#  'Vastagh': 'said',
#  'Natalie Koether': 'said',
#  'Abe': 'visit',
#  'Perry': 'day',
#  'Ali Akbar': 'spokesman',
#  'Jose Romero': 'chairman',
#  'Reuters': 'told',
#  'MLN STG': 'MONEY',
#  'Wolverine': 'said',
#  'Royal': 'said',
#  'Robert Maxwell': 'Harcourt',
#  'Stark': 'Iraqi',
#  'Paul Bilzerian': 'said',
#  'E.M. Warburg': 'Computerland',
#  'Allan Hawkins': 'said',
#  'Helmut Schmidt': 'former',
#  'Glynwed': 'Consideration',
#  'U.K. Economist': 'said',
#  'Du Plessis': 'rise',
#  'Herbert': 'said',
#  'Hawkins': 'said',
#  'Wilson': 'pct',
#  'Senegal': 'countries'}

# %%
organization_most_popular_terms
# Out:
# {'mln': 'dlrs',
#  'pct': 'said',
#  'cts': 'vs',
#  'QTR': 'NET',
#  'EC': 'said',
#  'Reuters': 'told',
#  'OPEC': 'said',
#  'USDA': 'said',
#  'MLN': 'DLRS',
#  'Fed': 'said',
#  'QTR NET': 'lt',
#  'Bundesbank': 'said',
#  'FED': 'SAYS',
#  'PCT': 'RATE',
#  'Treasury': 'said',
#  'GATT': 'trade',
#  'CTS': 'VS',
#  'Congress': 'said',
#  'Bank': 'stg',
#  'USAir': 'said',
#  'the Securities and Exchange Commission': 'said',
#  'ICO': 'said',
#  'TWA': 'USAir',
#  'OECD': 'said',
#  'The Bank of England': 'said',
#  'SEC': 'said',
#  'GenCorp': 'said',
#  'CCC': 'said',
#  'qtr': 'dlrs',
#  'House': 'trade',
#  'Co': 'said',
#  'Senate': 'said',
#  'BP': 'said',
#  'European Community': 'EC',
#  'treasury': 'bills',
#  'Chrysler': 'Renault',
#  'Oper': 'shr',
#  'Bank of Japan': 'yen',
#  'CSR': 'said',
#  'The U.S. Agriculture Department': 'tonnes',
#  'Lyng': 'said',
#  'Borg-Warner': 'said',
#  'GAF': 'said',
#  'Shearson': 'said',
#  'MITI': 'said',
#  'EMS': 'said',
#  'Texaco': 'said',
#  'Nakasone': 'said',
#  'NET': 'QTR',
#  'The Federal Reserve': 'said',
#  'Commission': 'said',
#  'CPC': 'said',
#  'LME': 'said',
#  'Merrill Lynch': 'said',
#  'the European Community': 'said',
#  'Kuwaiti': 'said',
#  'TREASURY': 'BAKER',
#  'Burlington': 'said',
#  'Hutton': 'said',
#  'American Express': 'said',
#  'IBC': 'said',
#  'Opec': 'said',
#  'Piedmont': 'shares',
#  'Taft': 'said',
#  'INRA': 'new',
#  'AMC': 'Chrysler',
#  'Agriculture': 'Secretary',
#  'Commerce': 'Secretary',
#  'Cyclops': 'Dixons',
#  'Viacom': 'dlrs',
#  'Hughes': 'said',
#  'U.S. Treasury': 'said',
#  'General Partners': 'said',
#  'Allied': 'said',
#  'Gillette': 'Revlon',
#  'LDP': 'said',
#  'Renault': 'Chrysler',
#  'TransCanada': 'Dome',
#  'The Bank of Japan': 'said',
#  'The Commodity Credit Corporation': 'said',
#  'Dome': 'said',
#  'Shell': 'said',
#  'the U.S. Agriculture Department': 'said',
#  'the Bank of Japan': 'said',
#  'the Bank of England': 'said',
#  'Cyacq': 'Cyclops',
#  'Ferruzzi': 'European',
#  'Community': 'EC',
#  'Finance': 'Minister',
#  'Citicorp': 'said',
#  'Co Inc': 'said',
#  'Sosnoff': 'Caesars',
#  'Parliament': 'told',
#  'the Federal Reserve': 'said',
#  'Federal Reserve Board': 'said',
#  'Purolator': 'said',
#  'Dixons': 'Cyclops',
#  'Sumita': 'said',
#  'ASA': 'said',
#  'Energy': 'oil',
#  'Exxon': 'said',
#  'White House': 'said',
#  'State': 'Secretary',
#  'Continental': 'said',
#  'UAL': 'stock',
#  'IBM': 'said',
#  'Finance Ministry': 'said',
#  'EEP': 'said',
#  'DOT': 'said',
#  'the World Bank': 'said',
#  'Revlon': 'Gillette',
#  'Standard': 'BP',
#  'Santa Fe': 'mm',
#  'the Securities and Exchange\n  Commission': 'told',
#  'Caesars World': 'said',
#  'central bank': 'said',
#  'Bankers': 'said',
#  'Cable': 'Wireless',
#  'Caesars': 'Sosnoff',
#  'Petrobras': 'oil',
#  'PDVSA': 'said',
#  'Emery': 'said',
#  'TMOC': 'dlrs',
#  'Bally': 'dlrs',
#  'Miyazawa': 'said',
#  'USX': 'said',
#  'Congressional': 'said',
#  'CGCT': 'French',
#  'Pesch': 'said',
#  'KLM': 'said',
#  'World Bank': 'said',
#  'Central Bank': 'billion',
#  'the Finance Ministry': 'billion',
#  'EIA': 'mln',
#  'the\n  Securities and Exchange Commission': 'pct',
#  'QTR OPER NET': 'CTS',
#  'Becor': 'said',
#  'SETS': 'QUARTERLY',
#  'The European Community': 'EC',
#  'UAE': 'Saudi',
#  'CBT': 'wheat',
#  'the International Monetary Fund': 'Bank',
#  'the U.S. Agriculture\n  Department': 'said',
#  'the Commerce Department': 'pct',
#  'Reed': 'said',
#  'Fujitsu': 'said',
#  'GM': 'said',
#  'PRT': 'field',
#  'Edelman': 'said',
#  'Group': 'mln',
#  'IEA': 'said',
#  'Gencorp': 'said',
#  'Woolworth': 'mln',
#  'UCPB': 'shares',
#  'Group of Seven': 'said',
#  'GE': 'dlrs',
#  'Noranda': 'said',
#  'AWB': 'said',
#  'Crazy Eddie': 'said',
#  'CTS VS': 'LOSS',
#  'Pentagon': 'said',
#  'Amstutz': 'said',
#  'MHI': 'pct',
#  'Citibank': 'rate',
#  'CRUDE': 'MLN',
#  'BIL': 'Progressive',
#  'Pennzoil': 'Texaco',
#  'Wireless': 'Cable',
#  'Campeau': 'Allied',
#  'Amoco': 'said',
#  'Cyclops Corp': 'said',
#  'GAO': 'certificates',
#  'API': 'mln',
#  'Silkworm': 'Iran',
#  'Wilson': 'said',
#  'Statistics Canada': 'pct',
#  'the U.S.\n  Agriculture Department': 'said',
#  'Mobil': 'said',
#  'Waste Management': 'said',
#  'Coastal': 'company',
#  'Nippon Life': 'Shearson',
#  'SGL': 'said',
#  'United': 'said',
#  'SOLD': 'EXPORTERS',
#  'ETL': 'said',
#  'the EC Commission': 'said',
#  'Bell': 'said',
#  '1986/87': 'mln',
#  'Council': 'said',
#  'the European\n  Community': 'EC',
#  'the White House': 'said',
#  'Reebok': 'shares',
#  'Samjens': 'Burlington',
#  'LPG': 'said',
#  'Pioneer': 'CSR',
#  'CTS/BBL': 'POSTINGS',
#  'Guinness': 'said',
#  'Baird': 'IV',
#  'Shearson Lehman Brothers': 'said',
#  'Sterling': 'dlrs',
#  'Foreign Ministry': 'told',
#  'Budget': 'said',
#  'The Commission': 'said',
#  'MERGE': 'lt',
#  'Newmont': 'dlrs',
#  'NA': 'Cherry',
#  'Chase': 'said',
#  'Qintex': 'said',
#  'Siemens': 'said',
#  'Cathay': 'pct',
#  'FNV': 'union',
#  'MARCH': 'PCT',
#  'American Motors': 'Chrysler',
#  'Administration': 'said',
#  'PIK': 'corn',
#  'Inc': 'said',
#  'Chemical': 'mln',
#  'Dealers': 'said',
#  'FTC': 'said',
#  'ONIC': 'French',
#  'First Boston': 'said',
#  'the Central Bank': 'billion',
#  'ATPC': 'said',
#  'Morgan Stanley': 'said',
#  'Tenneco': 'said',
#  'ICI': 'dlrs',
#  'CFTC': 'said',
#  'Air Canada': 'said',
#  'Harper and Row': 'said',
#  'CPB': 'pct',
#  'Norstar': 'shares',
#  'IWC': 'mln',
#  'Sumitomo': 'said',
#  'Oil World': 'said',
#  'SMC': 'shares',
#  'BID': 'Corp',
#  'Group of Five': 'Canada',
#  'GENCORP &lt;GY': 'GROUP',
#  'Balladur': 'said',
#  'Defense': 'Secretary',
#  'the Federal\n  Reserve': 'dlrs',
#  "Borg-Warner's": 'dlrs',
#  'The Commerce Department': 'billion',
#  'Ford': 'said',
#  'Boeing': 'shares',
#  'Petro-Canada': 'said',
#  'Unocal': 'said',
#  'Shearson Lehman': 'said',
#  'Weinberger': 'said',
#  'Resorts': 'said',
#  'NPPC': 'Pork',
#  'PSBR': 'stg',
#  'K Mart': 'said',
#  'Security Pacific': 'said',
#  'The Federal Home Loan Bank Board': 'rates',
#  'PaineWebber': 'said',
#  'UNIT': 'lt',
#  'Oppenheimer': 'said',
#  'E.F. Hutton': 'said',
#  'Entertainment Marketing': 'Crazy',
#  'ZCCM': 'kwacha',
#  'Cetus': 'Squibb',
#  'Kodak': 'said',
#  'NYMEX': 'prices',
#  'Jacobs': 'said',
#  'Agriculture Department': 'said',
#  'ICC': 'merger',
#  'Champion': 'said',
#  'USAir Group': 'TWA',
#  'Allied-Lyons': 'pct',
#  'Alusuisse': 'mln',
#  'TransAmerican': 'gas',
#  'American Medical': 'said',
#  'Liberal Democratic Party': 'ruling',
#  'the China Daily': 'said',
#  'Trade': 'said',
#  'Agriculture Ministry': 'said',
#  'Goldman Sachs': 'Co',
#  'Ministry': 'said',
#  'Bear Stearns': 'said',
#  'Consolidated': 'billion',
#  'the National Bank': 'Swiss',
#  'the U.S. Congress': 'said',
#  'Southmark': 'said',
#  'Westinghouse': 'mln',
#  'Customs': 'figures',
#  'Commonwealth': 'said',
#  'Federal Reserve': 'Paul',
#  'USAIR &lt;U': 'TWA',
#  'USAir Group Inc': 'said',
#  'Irving': 'said',
#  'ITC': 'International',
#  'IDC': 'lt',
#  'Shearson Lehman Brothers Inc': 'said',
#  'Union': 'said',
#  'Squibb': 'Cetus',
#  'the\n  European Community': 'EC',
#  'FDIC': 'said',
#  'Nippon': 'mln',
#  'CBI': 'pct',
#  'CRA': 'mln',
#  'DIW': 'Ifo',
#  'MALAYSIA': 'RUBBER',
#  'The EC Commission': 'said',
#  'the New York Stock Exchange': 'said',
#  'MLN STG': 'BIDS',
#  'MATURITY': 'days',
#  'GenCorp Inc': 'said',
#  'Istat': 'said',
#  'Computer Associates': 'said',
#  'the Federal Statistics Office': 'pct',
#  'Wagner': 'AFG',
#  'Loan Association': 'Savings',
#  'DOE': 'oil',
#  'FHLBB': 'Savings',
#  'Spectra-Physics': 'said',
#  'EC Commission': 'said',
#  'Mitsui': 'Co',
#  'Salomon': 'said',
#  'WEEK': 'BANK',
#  'State Department': 'said',
#  'U.S. Navy': 'Gulf',
#  'Chemical Bank': 'said',
#  'Metex': 'Metropolitan',
#  'Pillsbury': 'said',
#  'Alcan': 'said',
#  'Beghin-Say': 'sugar',
#  'Lloyds': 'said',
#  'EIU': 'said',
#  'the Reserve Bank': 'pct',
#  'the Securities\n  and Exchange Commission': 'said',
#  'Unilever': 'Stauffer',
#  'Dow': 'said',
#  'FAO': 'said',
#  'The World Bank': 'said',
#  'Esso': 'said',
#  "the U.S. Agriculture Department's": 'report',
#  'Farmers': 'dlrs',
#  'GRAIN': 'SHIPS',
#  'U.S. Agriculture Department': 'said',
#  'MTI': 'pct',
#  'Bangladesh': 'said',
#  'The Department': 'said',
#  'CME': 'futures',
#  'FERC': 'said',
#  'U.S. Government': 'said',
#  'MEES': 'said',
#  'Bank of England': 'said',
#  'ARCO': 'said',
#  'Allegheny International Inc': 'said',
#  'CHRYSLER': 'SETS',
#  'Chevron': 'said',
#  'CYCLOPS &lt;CYL': 'OPPENHEIMER',
#  'Navy': 'platform',
#  'Bull': 'Honeywell',
#  'Pantera': 'stock',
#  'BankAmerica': 'mln',
#  'Seipp': 'said',
#  'Allis-Chalmers': 'said',
#  'Chase Manhattan': 'said',
#  'Polaroid': 'said',
#  'Deutsche': 'billion',
#  'Audi': 'pct',
#  'First Interstate': 'banks',
#  'BAT': 'said',
#  'the Central Bureau of Statistics': 'pct',
#  'Buenos Aires': 'mm',
#  'WHITE HOUSE': 'SAYS',
#  'The White House': 'said',
#  'GMT': 'European',
#  'CANADA': 'SAID',
#  'HBO': 'said',
#  'MPT': 'said',
#  'U.S. Firms': 'said',
#  'Merrill': 'cash',
#  'the Reagan Administration': 'said',
#  'Bank of Canada': 'dlrs',
#  'National Bank': 'said',
#  'Phillips': 'Drew',
#  'Borg-Warner Corp': 'said',
#  'Standard Oil Co': 'said',
#  'Honeywell': 'said',
#  'Imperial': 'dlrs',
#  'FCC': 'said',
#  'Ciba-Geigy': 'said',
#  'USX &lt;X>': 'UNIT',
#  'Horner': 'said',
#  'European\n  Community': 'said',
#  'Greyhound': 'said',
#  '>': 'lt',
#  'First Federal': 'dlrs',
#  'PNG': 'cocoa',
#  'Bank of France': 'pct',
#  'Trans World Airlines Inc': 'USAir',
#  'Southland': 'stock',
#  'The Bank of France': 'market',
#  'CTC': 'Canadian',
#  'BHP': 'said',
#  'The Bank of Spain': 'money',
#  'NEC': 'pct',
#  'Delta': 'Western',
#  'Visa': 'credit',
#  'Utilicorp': 'mln',
#  'FDA': 'said',
#  'AGL': 'TMOC',
#  'Telecom': 'said',
#  'Placer': 'said',
#  'Holden-Brown': 'said',
#  'Co>': 'lt',
#  'THAI': 'RISE',
#  'NSW': 'New',
#  'FOB': 'dlrs',
#  'the Federal Reserve Board': 'said',
#  'The Finance Ministry': 'pct',
#  'Reserve Bank': 'rand',
#  'Ecu': 'price',
#  'Morgan': 'mln',
#  'Reuter': 'survey',
#  'Heineken': 'profit',
#  'NATO': 'Greece',
#  'Bureau': 'billion',
#  'Co Ltd': 'said',
#  'NASDAQ': 'said',
#  'NIL': 'Exports',
#  'IMF': 'National',
#  'Banco': 'Brasil',
#  'Smith Barney': 'said',
#  'Mellon': 'dlrs',
#  'SAMA': 'week',
#  'Wells Fargo': 'said',
#  'Caesars World Inc': 'Martin',
#  'Goodyear': 'said',
#  'ASCS': 'mln',
#  'MacAndrews': 'Revlon',
#  'BUYS': 'lt',
#  'Commerce Department': 'said',
#  'U.S. Trade': 'markets',
#  'RESULTS': 'lt',
#  'ICN': 'said',
#  'DIXONS': 'CYCLOPS',
#  'Standard Oil': 'BP',
#  'gm': 'octane',
#  'the European Monetary System': 'EMS',
#  'INDONESIA': 'PALM',
#  'KUWAIT': 'SAYS',
#  'Dayton Hudson': 'said',
#  'Tehran Radio': 'said',
#  'Outokumpu': 'division',
#  'Schlumberger': 'said',
#  'Icahn': 'said',
#  'Allegheny': 'company',
#  'Bank of New York': 'said',
#  'Morgan Grenfell': 'said',
#  'FOMC': 'policy',
#  'Department': 'said',
#  'Porsche': 'said',
#  'BANK OF CANADA': 'DLRS',
#  'Maekawa': 'report',
#  'Minstar': 'company',
#  'Henderson': 'said',
#  'Purolator Courier Corp': 'offer',
#  'Anacomp': 'said',
#  'Cenergy': 'said',
#  'AMI': 'Pesch',
#  'Fairchild': 'said',
#  'Harper': 'said',
#  'American Savings': 'said',
#  'Comecon': 'EC',
#  'ISO': 'tonnes',
#  'NMIC': 'said',
#  'APEA': 'said',
#  'Hk Hotels': 'Lau',
#  'Colombo': 'said',
#  'Komatsu': 'said',
#  'the European Commission': 'said',
#  'Inc>': 'lt',
#  'Proxmire': 'said',
#  'Exchequer': 'Chancellor',
#  'Montedison': 'billion',
#  'Chrysler Corp': 'said',
#  'MIM': 'pct',
#  'National': 'said',
#  'First Boston Corp': 'said',
#  'SPR': 'mln',
#  'Encor': 'Dome',
#  'Commerce Bank': 'said',
#  'Exxon Corp &lt;XON>': 'said',
#  'mln stg bank': 'bills',
#  'Chicago Mercantile Exchange': 'floor',
#  'E.F. Hutton LBO Inc': 'Purolator',
#  'Lawson': 'said',
#  "U.S. TREASURY'S": 'BAKER',
#  'Newmont Mining Corp': 'said',
#  'sulphur': 'pct',
#  'the Federal Reserve Bank': 'New',
#  'NSPA': 'said',
#  'Co Inc.': 'said',
#  'the U.S. Dollar': 'yen',
#  'BPI': 'Sanwa'}

# %%
location_most_popular_terms
# Out:
# {'Gulf': 'said',
#  'Europe': 'said',
#  'Africa': 'said',
#  'Asia': 'said',
#  'North Sea': 'oil',
#  'West': 'said',
#  'North America': 'said',
#  'the Middle East': 'said',
#  'the\n  Gulf': 'said',
#  'Middle East': 'oil',
#  'Western Europe': 'mln',
#  'Mediterranean': 'said',
#  'the Strait of Hormuz': 'said',
#  'Midwest': 'corn',
#  'the Gulf of Mexico': 'said',
#  'New England': 'dlrs',
#  '1986/87': 'mln',
#  'Mideast': 'oil',
#  'the North Sea': 'said',
#  'Latin America': 'dlrs',
#  'South America': 'said',
#  'the Far East': 'mln',
#  'Atlantic': 'said',
#  'Pacific': 'pipeline',
#  'West Texas': 'said',
#  'Western': 'said',
#  'the U.S. Gulf': 'dlrs',
#  'Far East': 'dlrs',
#  'FOB Gulf': 'dlrs',
#  'West Texas Sour': 'dlrs',
#  'South': 'said',
#  'the Aegean Sea': 'Turkish',
#  'East': 'West',
#  'Southeast Asia': 'said',
#  'Southern Pacific': 'Santa',
#  'Southwest': 'said',
#  'Prudhoe Bay': 'said',
#  'Persian Gulf': 'said',
#  'Eastern Europe': 'mln',
#  'Northeast': 'said',
#  'EUROPE': 'JAPAN',
#  'the Mideast Gulf': 'said',
#  'the Red River': 'pipeline',
#  'NORTH SEA': 'PANCANADIAN',
#  'Caribbean': 'countries',
#  'gulf': 'said',
#  'Bass Strait': 'pct',
#  'Delta': 'Western',
#  'Mississippi River': 'pct',
#  'Arabian Sea': 'Navy',
#  'the Gulf': 'said',
#  'west coast': 'Africa',
#  'Plaza': 'months',
#  'Terra Nova': 'company',
#  'Straits': 'Hormuz',
#  'Greens Creek': 'Co',
#  'the Northern Territory': 'pct',
#  'Highland Valley': 'Cominco',
#  'the East Coast': 'said',
#  'the Arctic National Wildlife Refuge': 'oil',
#  'Scandinavia': 'group',
#  'the Persian Gulf': 'Congress',
#  'Suez': 'tonnes',
#  'the West Coast': 'said',
#  'Southern California': 'Citicorp',
#  'the Black Sea': 'Soviet',
#  'Eastern Bloc': 'countries',
#  'West Coast': 'dlrs',
#  'midwest': 'would',
#  'North Yemen': 'Commodity',
#  'the Pacific coast': 'km',
#  'Avia': 'stock',
#  'East Bloc': 'diplomats',
#  'Louvre': 'said',
#  'North Sea Brent': 'crudes',
#  'Nova': 'Blair',
#  'East Coast': 'said',
#  'Gulf Coast': 'wells',
#  'Arctic': 'government',
#  'Jupiter': 'Corp',
#  'Mideast Gulf': 'Reagan',
#  'the Neutral Zone': 'Saudi',
#  'Central': 'South',
#  'the Cooper Basin': 'oil',
#  'the Middle\n  East': 'outside',
#  'South Yemen': 'MEES',
#  'Eastern\n  Bloc': 'However',
#  'the North China Plain': 'wheat',
#  'MidMississippi River': 'Corn',
#  'earth': 'could',
#  'Illinois River': 'Chicago',
#  'west': 'said',
#  'the Mississippi River': 'banks',
#  'the\n  gulf': 'told',
#  'South\n  Africa': 'said',
#  'the Far\n  East': 'Iranian',
#  'Sao\n  Paulo': 'Mato',
#  'the Pacific Ocean': 'pipeline',
#  'Pearl River': 'China',
#  'the Pacific Coast': 'pipeline',
#  'the middle east': 'government',
#  'the Texas Gulf Coast': 'dlrs',
#  'North\n  America': 'mln',
#  'the West': 'Western',
#  'San Joaquin Valley': 'Coast',
#  'Pacific Coast': 'northern',
#  'Continent': 'dlrs',
#  'trans-Atlantic': 'tonner',
#  'Northern Europe': 'crude',
#  'South East Asia': 'mln',
#  'Caicos Islands': 'VBI',
#  'Heidrun': 'Conoco',
#  'South Florida': 'said',
#  'the Southern District': 'Viacom',
#  'south central': 'storm',
#  'the South Pacific': 'dlrs',
#  'South-east': 'Bank',
#  'Northern California': 'Citicorp',
#  'Western\n  Europe': 'Malaysia',
#  'the Hormuz Strait': 'would',
#  'Kharg Island': 'Iran',
#  'the Beaufort Sea': 'gas',
#  'The Great Atlantic': 'Pacific',
#  'South Louisiana Sweet': 'dlrs',
#  'SOUTHERN GULF': 'AIRCRAFT',
#  'Ketza River': 'said',
#  'Smoky River': 'mln',
#  "Northern Star's": 'mln',
#  'Cenepa': 'Garcia',
#  'Queensland': 'Australian',
#  'Mackay': 'said',
#  'Asia-Pacific': 'open',
#  'the southwest Pacific': 'City',
#  'Valley': 'Inc',
#  'the Lower Valley': 'Cotton',
#  'the Bass Strait': 'first',
#  'West Europe': 'Japan',
#  'Lake Erie': 'Ontario',
#  'Kansai': 'international',
#  'Echo Bay': 'McCoy',
#  'the\n  Illinois': 'Corn',
#  'the Paris Basin': 'said',
#  'Buenos Aires': 'weather',
#  'the Red Sea': 'dlrs',
#  'North sea': 'dlrs',
#  'Western Australia': 'company',
#  'Cravo Norte': 'Petroleum',
#  'Amazon': 'oil',
#  'Yangtze': 'said',
#  'the Gulf war zone': 'Kuwait',
#  'Americas': 'businesses',
#  'the Uruguay Round': 'also',
#  'the\n  Mark': 'Bank',
#  'Central America': 'State',
#  'east coast': 'mln',
#  'the Southern Pacific': 'Santa',
#  'the Illinois River': 'Peoria',
#  'Wallenbergs': 'ST',
#  'Trump': 'Resorts',
#  'pacific': 'oil',
#  'S': 'mln',
#  'Muskeg Lake': 'property',
#  'the\n  Pacific': 'move',
#  'Yellow Sea': 'China',
#  'MIDEAST': 'AUSTRALIA',
#  'The Middle East': 'Gulf',
#  'Wood Mackenzie': 'stockbrokers',
#  'Lake Victoria': 'railway',
#  'Oak Harbour': 'Home',
#  'the\n  Neutral Zone': 'Current',
#  'Central\n  America': 'countries',
#  'Pivot': 'fire',
#  'Transvaal': 'agency',
#  "the Gulf of Mexico's": 'gas',
#  'the\n  bloc': 'EC',
#  'M0': 'Thomas',
#  'the Arabian Sea': 'Kitty',
#  'South Asia': 'Tropical',
#  'Baltic': 'icy',
#  'Suharto': 'see',
#  'North Island': 'meeting',
#  'Cooper Basin': 'oil',
#  'the Gulf area': 'Weinberger',
#  'Kittiwake': 'oil',
#  'Admiralty Island': 'ore',
#  'Middle South': 'court',
#  'the Adelaide River': 'located',
#  'Industrial Valley': 'assets',
#  'the Aegean\n  Sea': 'Turkey',
#  'Colville Delta': 'United',
#  'Eugene Island Block': 'Union',
#  'Old Crow': 'Analysts',
#  'the\n  West': 'Western',
#  'WEST COAST': 'TODD',
#  'Far\n  East': 'markets',
#  'Northern Hemisphere': 'buoyancy',
#  'Waccamaw': 'Anchor',
#  'east central': 'Corp',
#  'the Central District': 'subject',
#  'South East': 'X',
#  'Parana River': 'increased',
#  'Pacific ocean': 'new',
#  'Sime Darby': 'Since',
#  'Papuan\n  Basin': 'Merlin',
#  'the Gulf of Thailand': 'Oil',
#  'North America 334': 'mln',
#  'Central and South America 21': 'mln',
#  'Dome': 'shares',
#  'South Atlantic': 'share',
#  "South Atlantic's": 'Independence',
#  'Both South Atlantic': 'Independence',
#  'Duluth': 'officials',
#  'Midlantic': 'County',
#  'Paris Basin': 'mln',
#  'Sierras': 'Sales',
#  'Eastern Massachusetts': 'Accountemps',
#  'the Texas': 'wells',
#  'the Gulf of Suez': 'Canada',
#  'the Lago\n  Agrio': 'May',
#  'Bulolo Valley': 'metres',
#  '6.5/6.6 tonnes': 'yield',
#  'Rohm': 'said',
#  'Snyder': 'Geodyne',
#  'East Coast Sales': 'Semicon',
#  'the MIDEAST Gulf': 'Saying',
#  'Okla': 'Flooding',
#  'Lake Texoma': 'Texaco',
#  'Trigon': 'DOE',
#  'the South Australian\n  Cooper Basin': 'acquisition',
#  'the Jaffna peninsula': 'Sri',
#  'Johnny\n  Mountain Camp': 'said',
#  'the Mideast\n  Gulf': 'military',
#  'the western gulf': 'Caspar',
#  'Telegraph': 'Daily',
#  'the MidEast Gulf': 'leaders',
#  'the Gulf Arab states': 'force',
#  'barley': 'mln',
#  'Soil': 'moisture',
#  'the Japan Ship': 'gt',
#  'the Middle and Far East': 'Africa',
#  'Peninsula': 'Malaysia',
#  'the Eastern Hemisphere': 'Xerox',
#  'The West Texas Sour': 'grade',
#  'eastern seaboard': 'Gas',
#  'Red Sea': 'Iraq',
#  'the far east': 'Soviet',
#  'Dome\n  Mountain': 'Total',
#  'the Rhine river': 'Dutch',
#  'Southern Africa': 'Fifteen',
#  'Parachute Creek': 'Unocal',
#  'Koether': 'company',
#  'the Western Hemisphere': 'points',
#  'COFFEE QUOTAS UNCERTAIN': 'COLOMBIA',
#  'cif Mideast Gulf': 'propane',
#  'Gidgealpa South': 'production',
#  'Mideast Dubai': 'dlrs',
#  'the Western Corn Belt': 'Weekend',
#  'the central Midwest': 'move',
#  'the Corn Belt': 'could',
#  'Greenery': 'years',
#  "the Bay Area's": 'addition',
#  'the Sea Isle\n  City': 'Washington',
#  'the Artic Ocean': 'area',
#  'The West Texas': 'Sour',
#  'Gulf sea': 'captains',
#  'Southern Texas': 'said',
#  'Gold River': 'newsprint',
#  'the Sea Isle City': 'Iran',
#  'the Gulf Arab': 'escalation',
#  'Sea\n  Isle City': 'Weinberger',
#  'Southern Pafific Transportation': 'Fe',
#  'the Sea\n  Isle City': 'Attack',
#  'the Faw Peninsula': 'initial',
#  'the Gulf east': 'broadcast',
#  'Guernsey': 'BCI',
#  'Mount Snow': 'ski',
#  'San': 'ski',
#  'Central Soya': 'mln',
#  'Triton': 'company',
#  'Illinois Central Gulf': 'IC',
#  'Lavan island': 'oil',
#  "North Yemen's": 'discovery',
#  'North Sea Veslefrikk': 'field',
#  'the Gulf\n  war': 'Iran',
#  'Caspian Sea': 'Aqazadeh',
#  'South\n  East Asia': 'imports',
#  '4th qtr': 'vs',
#  'the Campos Basin': 'drop',
#  'KETZA RIVER': 'GOLD',
#  'Smoky River Coal': 'McIntyre',
#  'Smoky': 'McIntyre',
#  'valley': 'real',
#  'the Pacific Northwest': 'Department',
#  'New South Wales': 'group',
#  'Northern Star': 'dlrs',
#  'tonnes': 'Feb',
#  'FOB\n  Gulf': 'three',
#  'the Evros River': 'Greek',
#  'Thasos island': 'international',
#  'BfG': 'AMB',
#  'Skanska': 'said',
#  'Thassos': 'Aegean',
#  'Bow Valley': 'company',
#  'Norwest Gypsum': 'Louisiana',
#  'the Mediterranean': 'MEDITERRANEAN',
#  'the mediterranean region': 'Netback',
#  'Netbacks': 'Northern',
#  "Northern Europe's": 'Netbacks',
#  'Northern\n  Europe': 'Netbacks',
#  'Central Governmnet': 'added',
#  'South Texas': 'planting',
#  'Pine Bluff': 'filed',
#  'the North-West Shelf': 'largely',
#  'Danes': 'whichever',
#  'Bass\n  Strait': 'discoveries',
#  'Middle': 'decline',
#  'the\n  Atlantic': 'Last',
#  'these North Sea': 'crude',
#  'Republic': 'company',
#  'Lake Ontario': 'freight',
#  'Lake\n  Ontario': 'freight',
#  'New Harding': 'earlier',
#  'the Gulf of\n  Mexico': 'Shelf',
#  'the Upper Coast': 'Coastal',
#  'the Gulf or Great Lakes': 'Shipment',
#  'Southeast': 'Taiwan',
#  'Picardy': 'said',
#  'the south-east': 'pct',
#  'Georgia Gulf': 'mln',
#  'Kern River': 'crude',
#  'Illinois Central Gulf Railroad': 'subsidiary',
#  'the Eastern Coast': 'New',
#  "d'America e d'Italia": 'lt',
#  'the Gulf Coast': 'environmental',
#  'Silver': 'tonnes',
#  'Northern': 'California',
#  'Mile Island': 'dividend',
#  'Texas Gulf': 'structure',
#  'the Louisiana Gulf': 'Rumors',
#  'Baltic Sea': 'tonner',
#  'the Continent': 'Gulf',
#  'the Gulf to Jamaica': 'Grain',
#  'Cherry\n  Valley': 'Park',
#  'the\n  Rankin Inlet': 'gold',
#  'The\n  Tentonian': 'Publishers',
#  'the Indian Ocean': 'newspaper',
#  'the Strait of\n  Hormuz': 'said',
#  'the Central Asian\n  republic of Kazakhstan': 'situation',
#  'Central Bak': 'Egypt',
#  'Black Warrior Basin': 'company',
#  'mid-Atlantic': 'company',
#  'Canadian Tire': 'CTC',
#  'the Dallas Metroplex': 'practices',
#  'the Black\n  Sea coast': 'Winter',
#  'Keg River': 'wells',
#  'the Texas Gulf': 'Interior',
#  'Amoskeag': 'ramifications',
#  'Allegheny': 'suit',
#  '2nd qtr': 'dlrs',
#  'Algiers': 'Youcef',
#  'ASIA': 'PRESSURE',
#  "FEB\n  South Africa's": 'SHARPLY',
#  'Browns Creek': 'pct',
#  'the Black\n  Sea': 'Port',
#  'the Sea of Marmara': 'Port',
#  'the South Korean Won': 'Taiwan',
#  'the North\n  Sea': 'renewal',
#  'the Zurich Bourse': 'foreign',
#  'South-East Asia': 'Indonesia',
#  'the East coast': 'costs',
#  'Pearl River\n  Counties': 'Endevco',
#  'Gordon Lake': 'gold',
#  'the European\n  weekend': 'traditional',
#  'Waste': 'ChemLawn',
#  'Mossel Bay': 'Soekor',
#  'South Louisiana': 'Permian',
#  'The Mississippi River': 'open',
#  'the Aguarico river': 'also',
#  'Ecaudor': 'quake',
#  'the Ras Tanurah': 'mln',
#  'Nigerian Brass River': 'price',
#  'Beaufort Sea': 'Petroleum',
#  'South Bay': 'assets',
#  'the St Lawrence river': 'second',
#  'Port Moresby': 'said',
#  'Misima Island': 'Placer',
#  'the South China Sea': 'reported',
#  'South Bay S': 'mln',
#  'the Sea of\n  Marmara': 'Istanbul',
#  'Lake Michigan': 'Winds',
#  'south central Montana': 'western',
#  'Hudson Bay Mining': 'HUDSON',
#  'the Oak Hill': 'company',
#  'Oak Hill': 'company',
#  'Soo Line': 'loss',
#  'the Europe South': 'chairman',
#  'South-East': 'chairman',
#  'Southern Michigan': 'Sweet',
#  'the Arctic National Wildlife\n  Refuge': 'also',
#  'the South China': 'News',
#  'Continental Europe': 'mln',
#  'the\n  London': 'years',
#  'the South': 'mln',
#  'the\n  river': 'port',
#  'Hope Creek': 'said',
#  'the east coast': 'Ansbacher',
#  'Andes': 'Maoist',
#  'Boone Pickens': 'pure',
#  'the Henrique Leal': 'Port',
#  '3rd qtr': 'dlrs',
#  'the Great Plains': 'first',
#  'La\n  Pampa': 'mm',
#  'Corrientes': 'mm',
#  'Paradise Valley': 'Cotton',
#  'the Channel Island': 'Ward',
#  'Mid East': 'Sales',
#  'North America 34.7': 'mln',
#  'Club Med': 'would',
#  "the North Sea's": 'price',
#  'NORTH AMERICA': 'INC',
#  'RICE MARKET': 'ASK',
#  'Northern Alaska': 'National',
#  'the Welland\n  Canal': 'St',
#  'Lakes Erie': 'St',
#  'Seaway': 'entire',
#  'Med': 'Despite',
#  'the Western District': 'Alleghney',
#  'Weinberger': 'Defense',
#  'The barley area': 'ha',
#  'the Cook Strait': 'loading',
#  'AMAX Sleeper\n  Mine': 'Incx',
#  'Great America': 'Penn',
#  'Pacific Ocean': 'pipeline',
#  'the Pacific\n  Ocean': 'tremor',
#  'Fernando Valley': 'said',
#  "Beaver Creek's": 'dlrs',
#  'the Bay of Baes': 'separate',
#  'the Bay of Gabes': 'Work',
#  'Middle\n  East': 'fledgling',
#  'Central Queensland': 'pct',
#  'Mid-East Gulf': 'billion',
#  'Calny': 'Inc',
#  'Star Lake': 'said',
#  'Hudson Valley': 'provides',
#  'Mississippi': 'MEASURE',
#  'New York Harbor': 'rally',
#  'Central District': 'federal',
#  'the South West Advocate': 'lt',
#  'the South Bend Advocate': 'lt',
#  'Norhteast': 'said',
#  'Taft Broadcast': 'said',
#  'Southern France': 'Petroleum',
#  'Southern Europe': 'operations',
#  'the Southern Basin': 'pointed',
#  'the North China': 'February',
#  'Al-Wattari': 'noted',
#  'Allegheny Beverage': 'group',
#  "Allegheny Beverage's": 'revenues',
#  'Lynn Lake': 'owns',
#  'the Hudson Valley': 'assets',
#  'U.K. Base': 'market',
#  'south': 'however',
#  'the Midwest': 'byproduct',
#  'LFIO': 'earnings',
#  'the Polar Sea': 'government',
#  'Marble Hill': 'PSI',
#  'Hemdale': 'March',
#  'mlns tonnes': 'Czarnikow',
#  'Czarnikow': 'tonnes',
#  'Peerless Lake': 'oil',
#  'Marinduque Mining and Industrial\n  Corp': 'Manila',
#  'Key West Grill': 'Pillsbury',
#  'Oak Brook Hills\n  Hotel and Conference Center': 'company',
#  'the southern basin': 'restricted',
#  'central america': 'Martinez',
#  'south-Atlantic': 'states',
#  'Josten': 'Proprietary',
#  'the U.S. Mideast Task Force': 'Kitty',
#  "Western Australia's": 'belt',
#  "Asia-Pacific region's": 'Although',
#  'the Gulf of Bothnia': 'coastal',
#  'East bloc': 'questions',
#  'Pine\n  Bluff': 'Inc',
#  'the\n  Beaufort Sea': 'Gulf',
#  'the New Orleans Gulf': 'Sindt',
#  'Hawaiian Gardens': 'Compton',
#  "Hudson's Bay": 'shares',
#  'Six Flags': 'said',
#  "the Regent Sea's": 'Regency',
#  'the Regent Sea': 'dlrs',
#  'Kirkland Lake': 'exploration',
#  'Roman\n  Gralewicz': 'certain',
#  'the Oak Brook': 'company'}

# %% [markdown]
# ## Step 7) Present your results of the most popular entities and their associated terms

# %%
# present you results

# %%
import pandas as pd
def show_term_freqency(terms):
    a = pd.DataFrame(terms.values())
    a['count'] = 1
    a_sorted = a.groupby(by=0).count().sort_values(by='count', ascending=False)
    return a_sorted

# %%
show_term_freqency(person_most_popular_terms).head(10)
# Out:
#            count
# 0
# said         238
# dlrs          11
# pct           10
# mln            9
# President      5
# trade          5
# Prime          5
# chairman       5
# Minister       4
# Secretary      4

# %%
show_term_freqency(organization_most_popular_terms).head(10)
# Out:
#            count
# 0
# said         247
# pct           18
# dlrs          17
# mln           16
# lt             9
# billion        8
# EC             6
# shares         6
# Secretary      4
# told           4

# %%
show_term_freqency(location_most_popular_terms).head(10)
# Out:
#            count
# 0
# said          49
# mln           21
# dlrs          19
# company       12
# oil           11
# pct            6
# pipeline       5
# countries      3
# crude          3
# lt             3

# %% [markdown]
# ### My Findings
# The verb "said" is the most frequent term among person, organization, and location entities. Nevertheless, the most possible entity will occur is person entity when a sentence has the word "said". For person entities, there are some frequent political words "President", "chairman", "Minister", and "Secretary". For organization entities, there are some frequent business words like "shares". For location entities, there are some frequent words like "countries" and "oil."

# %% [markdown]
# ## Extra Credit
#
# There are several extra credit options for this assignment.
# * The first would be to determine which persons, organizations, and locations most frequently occur in the same sentences.
# * Another task would be to attempt to resolve different forms of the same name for each person and location. For example, George Bush and Bush inside the same document.
